# %%
import pandas as pd
from pandas import DataFrame
import main as main
import os

SRC_DIR =  'dataset/modern/full_dataset_20'

columns = [
    # 'temp_mid',
    # 'h', 
    'weight_kg', 
    'weight_perc_l3',
    # 't_perc_l10',
    # 'h_perc_l10',
]

# %%
files = os.listdir(SRC_DIR)
files
# Out:
# ['2022_152-h.csv',
#  '2022_82-.csv',
#  '2020_79-fts.csv',
#  '2022_97-.csv',
#  '2022_96-.csv']

# %%
index = 0

print(f'{index}/{len(files)}')
file = files[index]
df = pd.read_csv(f'{SRC_DIR}/{file}')

try:
    swarming_indexes = df[df['swarming'] == 1].index
    queencell_indexes = df[df['queencell'] == 1].index
    feeding_indexes = df[df['feeding'] == 1].index
    honey_indexes = df[df['honey'] == 1].index
    treatment_indexes = df[df['treatment'] == 1].index
    died_indexes = df[df['died'] == 1].index
except:
    swarming_indexes = []
    queencell_indexes = []
    feeding_indexes = []
    honey_indexes = []
    treatment_indexes = []
    died_indexes = []

print (f'SW {len(swarming_indexes)},    QC {len(queencell_indexes)},    F {len(feeding_indexes)},   H {len(honey_indexes)},   T   {len(treatment_indexes)},    D {len(died_indexes)}')
for col in columns:
    title = os.path.basename(file) + ' == ' + col
    main.show_graph(df[col], title, swarming_indexes, queencell_indexes, feeding_indexes, honey_indexes, treatment_indexes, died_indexes)
# Out:
# 0/5
# SW 0,    QC 0,    F 0,   H 0,   T   0,    D 0
# /var/folders/8g/gbqqwv9j035d81xb9dz_s6kw0000gn/T/ipykernel_2850/196354759.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{SRC_DIR}/{file}')
